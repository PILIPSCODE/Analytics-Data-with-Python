# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Pilipus Kuncoro Wismoady
# - **Email:** anonymskunay@gmail.com
# - **ID Dicoding:** [anonyms_kunay_J7BT]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apakah kualitas udara di stasiun tertentu lebih baik atau lebih buruk dibandingkan dengan stasiun lainnya?
# - Apakah terdapat perbedaan yang signifikan dalam kualitas udara antara bulan-bulan musim panas dan musim dingin selama periode 2013 hingga 2017?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Aotizhongxin_station_df = pd.read_csv("Dataset/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
Changping_station_df = pd.read_csv("Dataset/PRSA_Data_Changping_20130301-20170228.csv")
Dingling_station_df = pd.read_csv("Dataset/PRSA_Data_Dingling_20130301-20170228.csv")
Dongsi_station_df = pd.read_csv("Dataset/PRSA_Data_Dongsi_20130301-20170228.csv")
Guanyuan_station_df = pd.read_csv("Dataset/PRSA_Data_Guanyuan_20130301-20170228.csv")
Gucheng_station_df = pd.read_csv("Dataset/PRSA_Data_Gucheng_20130301-20170228.csv")
Huairou_station_df = pd.read_csv("Dataset/PRSA_Data_Huairou_20130301-20170228.csv")
Nongzhanguan_station_df = pd.read_csv("Dataset/PRSA_Data_Nongzhanguan_20130301-20170228.csv")
Shunyi_station_df = pd.read_csv("Dataset/PRSA_Data_Shunyi_20130301-20170228.csv")
Tiantan_station_df = pd.read_csv("Dataset/PRSA_Data_Tiantan_20130301-20170228.csv")
Wanliu_station_df = pd.read_csv("Dataset/PRSA_Data_Wanliu_20130301-20170228.csv")
Wanshouxigong_station_df = pd.read_csv("Dataset/PRSA_Data_Wanshouxigong_20130301-20170228.csv")

# %%
Aotizhongxin_station_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Changping_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
Dingling_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
Dongsi_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
Guanyuan_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
Gucheng_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
Huairou_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
Nongzhanguan_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
Shunyi_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
Tiantan_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
Wanliu_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
Wanshouxigong_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# **Insight:**
# - Mengakses semua data
# - Dan Mengecek menggunakan head method

# %% [markdown]
# ### Assessing Data

# %%
Aotizhongxin_station_df.info()
Aotizhongxin_station_df.duplicated().sum()
Aotizhongxin_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Changping_station_df.info()
Changping_station_df.duplicated().sum()
Changping_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Dingling_station_df.info()
Dingling_station_df.duplicated().sum()
Dingling_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Dongsi_station_df.info()
Dongsi_station_df.duplicated().sum()
Dongsi_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Guanyuan_station_df.info()
Guanyuan_station_df.duplicated().sum()
Guanyuan_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Gucheng_station_df.info()
Gucheng_station_df.duplicated().sum()
Gucheng_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Huairou_station_df.info()
Huairou_station_df.duplicated().sum()
Huairou_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Nongzhanguan_station_df.info()
Nongzhanguan_station_df.duplicated().sum()
Nongzhanguan_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Shunyi_station_df.info()
Shunyi_station_df.duplicated().sum()
Shunyi_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Tiantan_station_df.info()
Tiantan_station_df.duplicated().sum()
Tiantan_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Wanliu_station_df.info()
Wanliu_station_df.duplicated().sum()
Wanliu_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
Wanshouxigong_station_df.info()
Wanshouxigong_station_df.duplicated().sum()
Wanshouxigong_station_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %% [markdown]
# - Pada semua DataFrame memiliki beberapa nilai null pada column "PM2.5", "PM10", "SO2", "NO2", "CO", "O3"
# - Pada semua DataFrame tidak ada data duplikasi
# - Pada semua DataFrame Terdapat inaccurate data pada column "PM2.5","PM10","CO","O3"

# %% [markdown]
# ### Cleaning Data

# %%
def clean_data(df):
    df = df[df["PM2.5"] < 300]
    df = df[df["PM10"] < 500]
    df = df[df["O3"] < 270]
    return df

Tiantan_station_df = clean_data(Tiantan_station_df)
Aotizhongxin_station_df = clean_data(Aotizhongxin_station_df)
Changping_station_df = clean_data(Changping_station_df)
Dingling_station_df = clean_data(Dingling_station_df)
Dongsi_station_df = clean_data(Dongsi_station_df)
Gucheng_station_df = clean_data(Gucheng_station_df)
Guanyuan_station_df = clean_data(Guanyuan_station_df)
Huairou_station_df = clean_data(Huairou_station_df)
Shunyi_station_df = clean_data(Shunyi_station_df)
Nongzhanguan_station_df = clean_data(Nongzhanguan_station_df)
Wanliu_station_df = clean_data(Wanliu_station_df)
Wanshouxigong_station_df = clean_data(Wanshouxigong_station_df)

# %%
all_df = [Aotizhongxin_station_df, Changping_station_df, Dingling_station_df, Dongsi_station_df, Guanyuan_station_df, Gucheng_station_df, Huairou_station_df, Nongzhanguan_station_df, Shunyi_station_df, Tiantan_station_df, Wanliu_station_df, Wanshouxigong_station_df]
mean_cols = ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]

# %%
for DataFrame in all_df:
    DataFrame["CO"] = DataFrame["CO"]/1000  # Ubah Satuan µg/m³ menjadi mg/m³

# %%
for i, DataFrame in enumerate(all_df):
    DataFrame.drop(columns=["TEMP", "PRES", "DEWP", "RAIN", "wd", "WSPM"], inplace=True)
    for cols in mean_cols:
        DataFrame[cols].fillna(value=DataFrame[cols].mean(), inplace=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_7724\1425056819.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DataFrame[cols].fillna(value=DataFrame[cols].mean(), inplace=True)
# C:\Users\acer\AppData\Local\Temp\ipykernel_7724\1425056819.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
Aotizhongxin_station_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   31989.000000  31989.000000  31989.000000  31989.000000  31989.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17585.582669   2014.677827      6.414111     15.679390     11.574698
# std     10173.528886      1.178669      3.391770      8.785105      6.900924
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8869.000000   2014.000000      3.000000      8.000000      6.000000
# 50%     17710.000000   2015.000000      6.000000     16.000000     12.000000
# 75%     26458.000000   2016.000000      9.000000     23.000000     18.000000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
#cek data 
Aotizhongxin_station_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Mengisi Semua nilai kosong pada ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"] dengan rata-rata
# - Menghapus column yang tidak penting ["TEMP", "PRES", "DEWP", "RAIN", "wd", "WSPM"]
# - Menghapus semua inaccurate data pada column "PM2.5","PM10","CO","O3"

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Dingling_station_df.describe(include="all")
# Aotizhongxin_station_df.describe(include="all")
# Dongsi_station_df.describe(include="all")
# Changping_station_df.describe(include="all")
# Gucheng_station_df.describe(include="all")
# Guanyuan_station_df.describe(include="all")
# Huairou_station_df.describe(include="all")
# Nongzhanguan_station_df.describe(include="all")
# Shunyi_station_df.describe(include="all")
# Tiantan_station_df.describe(include="all")
# Wanliu_station_df.describe(include="all")
Wanshouxigong_station_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   32492.000000  32492.000000  32492.000000  32492.000000  32492.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17576.641820   2014.671704      6.476179     15.670411     11.488674
# std     10097.820667      1.173364      3.399523      8.772204      6.906746
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      9072.750000   2014.000000      4.000000      8.000000      6.000000
# 50%     17663.500000   2015.000000      7.000000     16.000000     11.000000
# 75%     26328.250000   2016.000000      9.000000     23.000000     17.000000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %% [markdown]
# - https://www.airnow.gov/aqi/aqi-basics/
#
# | AQI Basics  | Kategori                             |
# |------------|---------------------------------------|
# | 0 - 50     | Baik                                 |
# | 51 - 100   | Sedang                               |
# | 101 - 150  | Tidak Sehat untuk Kelompok Sensitif   |
# | 151 - 200  | Tidak Sehat                          |
# | 201 - 300  | Sangat Tidak Sehat                   |
# | 301 - 500  | Berbahaya                            |
#
#
# -------------------------------
#
# -https://www.who.int/news-room/fact-sheets/detail/ambient-(outdoor)-air-quality-and-health
#
#
# | AQI Category                    | PM2.5 (µg/m³)      | PM10 (µg/m³)      |
# |----------------------------------|--------------------|-------------------|
# | Good                             | 0.0 - 12.0         | 0.0 - 54.0        |
# | Moderate                         | 12.1 - 35.4        | 55.0 - 154.0      |
# | Unhealthy for Sensitive Groups   | 35.5 - 55.4        | 155.0 - 254.0     |
# | Unhealthy                        | 55.5 - 150.4       | 255.0 - 354.0     |
# | Very Unhealthy                   | 150.5 - 250.4      | 355.0 - 424.0     |
# | Hazardous                        | ≥ 250.5            | ≥ 425.0           |

# %%
def calculate_aqi(AQI):
    if AQI >= 301:
        return "Hazardous"
    elif AQI >= 201:
        return "Very Unhealthy"
    elif AQI >= 151:
        return "Unhealthy"
    elif AQI >= 101:
        return "Unhealthy for Sensitive Groups"
    elif AQI >= 51:
        return "Moderate"
    else:
        return "Good"
    
def calculate_pm25(pm25_value):
    if pm25_value >= 250.4:
        return "Hazardous"
    elif pm25_value >= 150.4:
        return "Very Unhealthy"
    elif pm25_value >= 55.5:
        return "Unhealthy for Sensitive Groups"
    elif pm25_value >= 35.5:
        return "Unhealthy"
    elif pm25_value >= 12.1:
        return "Moderate"
    else:
        return "Good"

def calculate_pm10(pm10_value):
    if pm10_value >= 425.0:
        return "Hazardous"
    elif pm10_value >= 355.0:
        return "Very Unhealthy"
    elif pm10_value >= 255.0:
        return "Unhealthy for Sensitive Groups"
    elif pm10_value >= 155.0:
        return "Unhealthy"
    elif pm10_value >= 55.0:
        return "Moderate"
    else:
        return "Good"

# %% [markdown]
# hapus semua keterangan waktu ubah menjadi tanggal, selanjutnya buat column AQI dengan mengambil polutan dengan nilai tertinggi, setelah itu gabungkan semua

# %%
df_names = ['Aotizhongxin_station_df', 'Changping_station_df', 'Dingling_station_df', 
            'Dongsi_station_df', 'Guanyuan_station_df', 'Gucheng_station_df', 
            'Huairou_station_df', 'Nongzhanguan_station_df', 'Shunyi_station_df', 
            'Tiantan_station_df', 'Wanliu_station_df', 'Wanshouxigong_station_df']


for i,df in enumerate(all_df):
    df['date'] = pd.to_datetime(df[['year', 'month', 'day']])
    df.drop(columns=["No","year","day","hour"])

    #Ambil konsentrasi dengan nilai tertinggi, sesuai standart AQI
    df['AQI'] = df[['PM2.5', 'PM10', 'SO2', 'CO', 'O3','NO2']].max(axis=1)
    exec(f"{df_names[i]} = df")
    
merged_all_df = pd.concat(all_df, ignore_index=True)

# %%
merged_all_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2   CO    O3  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  0.3  77.0
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  0.3  77.0
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  0.3  73.0
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  0.3  72.0
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  0.3  72.0
#
#         station       date   AQI
# 0  Aotizhongxin 2013-03-01  77.0
# 1  Aotizhongxin 2013-03-01  77.0
# 2  Aotizhongxin 2013-03-01  73.0
# 3  Aotizhongxin 2013-03-01  72.0
# 4  Aotizhongxin 2013-03-01  72.0

# %% [markdown]
# menggabungkan semua data frame menjadi time frame bulanan

# %%
monthly_AQI_df = merged_all_df.resample(rule='ME', on='date').agg({
        "AQI": "median",
        
})
monthly_AQI_df.index = monthly_AQI_df.index.strftime('%B')

AQI_Station = merged_all_df.groupby(by="station")["AQI"].median().sort_values(ascending=True).reset_index()
AQI_Station["category"] = AQI_Station["AQI"].apply(lambda x: calculate_aqi(x))

# %%
monthly_AQI_df.head(10)
# Out:
#                 AQI
# date
# March      111.0000
# April      103.0000
# May        135.0000
# June       138.0000
# July       111.0000
# August     101.0000
# September  101.0000
# October     89.8749
# November    68.0000
# December    71.0000

# %%
AQI_Station.head()
# Out:
#      station    AQI                        category
# 0   Dingling   89.0                        Moderate
# 1    Huairou   90.0                        Moderate
# 2  Changping   91.0                        Moderate
# 3     Shunyi   96.0                        Moderate
# 4    Tiantan  102.0  Unhealthy for Sensitive Groups

# %% [markdown]
# ## sumber
# - https://seasonsyear.com/China
# - https://www.chinadiscovery.com/weather.html
# - https://en.wikipedia.org/wiki/Climate_of_China
# - https://www.chinahighlights.com/weather/
# - https://www.chinadiscovery.com/weather/winter.html

# %% [markdown]
# Dari sumber tersebut bulan musim panas dicina pada tahun 2013 - 2017 dimulai dari april - agustus, sedangkan musim dingin oktober - january

# %%
def Season(month):
    if month == "April" or month == "May" or month == "June" or month == "July" or month == "August":
        return "Summer"
    elif month == "November" or month == "December" or month == "January":
         return "Winter"
    elif month == "September" or month == "October":
        return "Autumn"
    else:
        return "Spring"

# %% [markdown]
# Mengubah Urutan Bulan

# %% [markdown]
# **Insight:**
# - Mencari categori untuk mengetahui apakah udara sehat atau tidak sehat
# - mengabungkan semua dataframe menjadi bulanan dan kualitas udara setiap station
# - Mencari bulan bulan Musim dicina pada tahun 2013-2017

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
# Apakah kualitas udara di stasiun tertentu lebih baik atau lebih buruk dibandingkan dengan stasiun lainnya?

# %%
colors = ["#ffcc00","#ff6666"]
plt.subplots(figsize=(10, 6))
sns.barplot(y="station", x="AQI", hue="category", palette=colors,data=AQI_Station)
plt.title("Air Quality all Station (2013-2017)", loc="center", fontsize=20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Apakah ada perbedaan yang signifikan dalam kualitas udara antara bulan-bulan musim panas dan musim dingin ditahun tersebut?

# %%
monthly_Station = monthly_AQI_df.groupby(by="date")["AQI"].median().reset_index()
monthly_Station ["category"] = monthly_Station["AQI"].apply(lambda x: calculate_aqi(x))

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_Station['date'] = pd.Categorical(monthly_Station['date'], categories=month_order, ordered=True)


monthly_Station_sorted = monthly_Station.sort_values('date').reset_index(drop=True)


monthly_Station_sorted["season"] = monthly_Station_sorted["date"].apply(lambda x: Season(x))

monthly_Station_sorted
# Out:
#          date        AQI                        category  season
# 0     January   88.00000                        Moderate  Winter
# 1    February   88.50000                        Moderate  Spring
# 2       March  117.00000  Unhealthy for Sensitive Groups  Spring
# 3       April  113.00000  Unhealthy for Sensitive Groups  Summer
# 4         May  115.50000  Unhealthy for Sensitive Groups  Summer
# 5        June  112.00000  Unhealthy for Sensitive Groups  Summer
# 6        July  107.50000  Unhealthy for Sensitive Groups  Summer
# 7      August   99.00000                        Moderate  Summer
# 8   September   90.00000                        Moderate  Autumn
# 9     October   87.93745                        Moderate  Autumn
# 10   November   83.00000                        Moderate  Winter
# 11   December   82.00000                        Moderate  Winter

# %%
colour = ["#3DC8EF","#099E42","#F8060A","#FD7D00"]



fig = plt.subplots(figsize=(20, 5))
sns.lineplot(x='date', y='AQI', data=monthly_Station_sorted, markerfacecolor='limegreen',linewidth=4,color="black", marker="o",markersize=9)
plt.title("Comparison of Air Quality Between All Season(2013-2017)", loc="center", fontsize=20)


sns.barplot(y="AQI" , x="date",color="#D3D3D3" , hue="season", palette=colour, data=monthly_Station_sorted)
plt.show()

# %% [markdown]
# **Insight:**
# - Menggunkan Bar plot untuk memvisualisasikan data, yang sudah dikelompokan berdasarkan station
# - Menggunakan Bar plot, Line plot untuk memvisualisasikan data, dari semua station yang digabungkan berdasarkan bulan

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# Clustering (Manual Grouping)

# %%
merged_all_df["category"] = merged_all_df["AQI"].apply(lambda x: calculate_aqi(x))

AQI_Category_df = merged_all_df.groupby(by="category").agg({
    "AQI":"count"
}).reset_index()

AQI_Category_df.head(10)
# Out:
#                          category     AQI
# 0                            Good   45194
# 1                       Hazardous    5935
# 2                        Moderate  151181
# 3                       Unhealthy   55042
# 4  Unhealthy for Sensitive Groups   87844
# 5                  Very Unhealthy   46663

# %%
colors = ['#2FCA30', '#660099', '#ffcc00', '#FE0000', '#ff6666', '#9B30FF']
sizes = AQI_Category_df['AQI'] 
labels = AQI_Category_df['category']

plt.figure(figsize=(6, 6))  
plt.pie(sizes, labels=labels, colors=colors,  autopct='%1.1f%%', startangle=90)

plt.axis('equal')

plt.title('Distribution of AQI Categories')

plt.show()

# %%
merged_all_df["PM2.5_Category"] = merged_all_df["PM2.5"].apply(lambda x: calculate_pm25(x))

AQI_by_PM25 = merged_all_df.groupby(by="PM2.5_Category")["PM2.5"].count().reset_index()

# %%
sizes = AQI_by_PM25['PM2.5']
labels =AQI_by_PM25["PM2.5_Category"]

plt.figure(figsize=(6, 6))  
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

plt.axis('equal')

plt.title('Distribution of PM2.5 AQI Categories')

plt.show()

# %%
merged_all_df["PM10_Category"] = merged_all_df["PM10"].apply(lambda x: calculate_pm10(x))

AQI_by_PM10 = merged_all_df.groupby(by="PM10_Category")["PM10"].count().reset_index()
AQI_by_PM10.head()
# Out:
#                     PM10_Category    PM10
# 0                            Good  145755
# 1                       Hazardous     456
# 2                        Moderate  166867
# 3                       Unhealthy   62210
# 4  Unhealthy for Sensitive Groups   15227

# %%
sizes = AQI_by_PM10["PM10"]
labels = AQI_by_PM10["PM10_Category"]

plt.figure(figsize=(6, 6))  
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=25)

plt.axis('equal')

plt.title('Distribution of PM10 AQI Categories')

plt.show()

# %%
colors = ['#2FCA30', '#660099', '#ffcc00', '#FE0000', '#ff6666', '#9B30FF']
sizes1 = AQI_Category_df['AQI'] 
labels1 = AQI_Category_df['category']

sizes2 = AQI_by_PM10["PM10"]
labels2 = AQI_by_PM10["PM10_Category"]

sizes3 = AQI_by_PM25['PM2.5']
labels3 =AQI_by_PM25["PM2.5_Category"]


fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(35, 15)) 


# Plot pie chart for AQI categories
ax[0].pie(sizes1, labels=labels1, colors=colors, autopct='%1.1f%%', startangle=90)
ax[0].axis('equal')
ax[0].set_title('Distribution of AQI Categories')

# Plot pie chart for PM10 categories
ax[1].pie(sizes2, labels=labels2, colors=colors, autopct='%1.1f%%', startangle=90)
ax[1].axis('equal')
ax[1].set_title('Distribution of PM10 Categories')

# Plot pie chart for PM2.5 categories
ax[2].pie(sizes3, labels=labels3, colors=colors, autopct='%1.1f%%', startangle=90)
ax[2].axis('equal')
ax[2].set_title('Distribution of PM2.5 Categories')

plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# -  Bisa Kita lihat dari grafik tersebut bahwa kualitas udara di station Dingling adalah station yang memiliki pengukuran udara terbersih karena rata-rata AQI Berada di 51 - 100 yang berarti Moderate, sedangkan Gucheng memiliki Udara terkotor karena rata-rata AQI Berada di 101 - 150 yang berarti Unhealthy for sensitive Groups
# - Bisa Kita Lihat dari grafik Pada bulan bulan musim Panas Kualitas Udara cenderung memburuk dibanding musim dingin
# - dari analisa lanjutan sebagian besar aqi berada di tingkat moderate
